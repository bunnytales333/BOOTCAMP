# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

data = {
    "Year": np.arange(1990, 2025, 5),
    "Population": [5.3, 5.7, 6.1, 6.5, 6.9, 7.3, 7.7], 
    "Cell Phones": [0.1, 0.5, 1.2, 2.5, 4.0, 6.5, 8.2] 
}

df = pd.DataFrame(data)

df["Cell Phones per Person"] = df["Cell Phones"] / df["Population"]

plt.figure(figsize=(10, 6))
plt.plot(df["Cell Phones per Person"], df["Year"], marker='o', linestyle='-', label="Cell Phones per Person")
plt.xlabel("Number of Cell Phones per Person")
plt.ylabel("Year")
plt.title("Rise of Cell Phones per Person Over Time")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
data = {
    "Year": np.arange(1990, 2025, 5),
    "Population": [5.3, 5.7, 6.1, 6.5, 6.9, 7.3, 7.7],  
    "Cell Phones": [0.1, 0.5, 1.2, 2.5, 4.0, 6.5, 8.2]  
}

df = pd.DataFrame(data)

df["Cell Phones per Person"] = df["Cell Phones"] / df["Population"]
dbutils.widgets.text("start_year", "1990")  
dbutils.widgets.text("end_year", "2025")

start_year = int(dbutils.widgets.get("start_year"))
end_year = int(dbutils.widgets.get("end_year"))
df_filtered = df[(df["Year"] >= start_year) & (df["Year"] <= end_year)]
plt.figure(figsize=(10, 6))
plt.plot(df_filtered["Cell Phones per Person"], df_filtered["Year"], marker='o', linestyle='-', label="Cell Phones per Person")
plt.xlabel("Number of Cell Phones per Person")
plt.ylabel("Year")
plt.title("Rise of Cell Phones per Person Over Time")
plt.legend()
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 6))
plt.bar(df_filtered["Year"], df_filtered["Cell Phones"], color='blue', alpha=0.6, label="Cell Phones (Billion)")
plt.bar(df_filtered["Year"], df_filtered["Population"], color='green', alpha=0.6, label="Population (Billion)")
plt.xlabel("Year")
plt.ylabel("Count (Billion)")
plt.title("Comparison of Cell Phones and Population")
plt.legend()
plt.grid(True)
plt.show()

display(df_filtered)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Population</th><th>Cell Phones</th><th>Cell Phones per Person</th></tr></thead><tbody><tr><td>1990</td><td>5.3</td><td>0.1</td><td>0.01886792452830189</td></tr><tr><td>1995</td><td>5.7</td><td>0.5</td><td>0.08771929824561403</td></tr><tr><td>2000</td><td>6.1</td><td>1.2</td><td>0.19672131147540983</td></tr><tr><td>2005</td><td>6.5</td><td>2.5</td><td>0.38461538461538464</td></tr><tr><td>2010</td><td>6.9</td><td>4.0</td><td>0.5797101449275363</td></tr><tr><td>2015</td><td>7.3</td><td>6.5</td><td>0.8904109589041096</td></tr><tr><td>2020</td><td>7.7</td><td>8.2</td><td>1.0649350649350648</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
